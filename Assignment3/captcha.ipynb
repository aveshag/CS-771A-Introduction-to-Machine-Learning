# %%
import cv2
import os
import glob
import numpy as np
import matplotlib.pyplot as plt
import time as tm

# %%
train = "train"
split_img = "split_img"
os.system('rm -rf split_img')
try:
    os.mkdir(split_img)
except:
    garbage = 0


for i in range(65,91):
    try:
        os.mkdir(split_img + "/" + chr(i))
    except: 
        garbage = 0
       
captchas = glob.glob(os.path.join(train, "*"))


# count = np.zeros([256])
# captcha = "train/QDMK.png"
# img = cv2.imread(captcha,0)

# cv2.imshow('image',img)
# cv2.waitKey(0)
# cv2.destroyAllWindows()

# for i in range(len(img)) :  
#     for j in range(len(img[i])) :  
#         count[img[i][j]] += 1
# sort_count = np.sort(count)
# sort_ind = np.argsort(count)[-20:-1]
# print(sort_ind)

# for i in range(len(img)) :  
#     for j in range(len(img[i])) :  
#         flag = 0
#         for k in sort_ind :
#             if(img[i][j] == k) :
#                 flag = 1
#                 break
#         if(flag == 1):
#             img[i][j] = 0
#         else:
#             img[i][j] = 255
            
# cv2.imshow('image',img)
# cv2.waitKey(0)
# cv2.destroyAllWindows()
tic = tm.perf_counter()

count = 0
for (i, captcha) in enumerate(captchas):
#     captcha = "train/EGN.png"
#     print(captcha,i)
    img = cv2.imread(captcha)   #read image as grayscale
    print(captcha)
#     cv2.imshow('image',img)
#     cv2.waitKey(0)
#     cv2.destroyAllWindows()
    
    first_px = img[0,0]
    img[np.where(img == first_px)] = 0
    
    kernel = np.ones((6,6),np.uint8)
    erosion = cv2.erode(img, kernel, iterations = 1)  
    img = cv2.morphologyEx(erosion, cv2.MORPH_OPEN, kernel)
    #dilation = cv2.dilate(img,kernel,iterations = 1)
#     img=erosion
    img[np.where(img == 0)] = 255
    img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    
    img[np.where(img != 255)] = 0
    
    crop_s = []
    crop_e = []
    
    start = 0
    end = 0
    flag = 1
    
    
    img = np.transpose(img)
    
    #print(len(img))
    
    num_px = 0 # number of pixels
    
    for i in range(len(img)):
        if  flag and np.sum(img[i]) != 255*(len(img[i])) :
            start = i
            flag = 0
        elif flag == 0 and np.sum(img[i]) == 255*(len(img[i])) :
            flag = 1;
            mid = int((i + start)/2)
            if i - start > 25 and np.sum(img[mid])<(255*(len(img[mid])-10)):
                crop_s.append(start)
                crop_e.append(i)
    #print(crop)
    
    img = np.transpose(img)
#     cv2.imshow('image',img)
#     cv2.waitKey(0)
#     cv2.destroyAllWindows()
    filename = os.path.basename(captcha)
    captcha_text = os.path.splitext(filename)[0]
    if (len(crop_s)-len(captcha_text)) != 0 :
        print(captcha_text)
        print(len(crop_s))
        print(len(captcha_text))
    for i in range(len(crop_s)):
        if i == len(captcha_text):
            break
        x_ = crop_s[i]
        y_ = crop_e[i]
        crop_img = img[:,x_-5:y_+5]
        save_path = os.path.join(split_img, captcha_text[i])
        p = os.path.join(save_path, "{}.png".format(str(count)))
        cv2.imwrite(p, crop_img)
        count += 1
        
#         cv2.imshow(captcha_text[i] + ".png", crop_img)
#         cv2.waitKey(0)
#         cv2.destroyAllWindows()
#     break

toc = tm.perf_counter()
print(toc-tic)
# Out:
# train/FBF.png
# train/EPOV.png
# train/MDN.png
# train/KQH.png
# train/PFNO.png
# train/LCH.png
# train/PFU.png
# train/RQO.png
# train/GMMU.png
# train/XQO.png
# train/AING.png
# train/TNZJ.png
# train/TNG.png
# train/CJF.png
# train/QUM.png
# train/GYZ.png
# train/OWFW.png
# train/GYY.png
# train/HLR.png
# train/ACF.png
# train/RSKC.png
# train/LYL.png
# train/PIPI.png
# train/TSNL.png
# train/TRWJ.png
# train/SYL.png
# train/MDA.png
# train/FLTG.png
# train/MVKF.png
# train/WJMM.png
# train/SKNM.png
# train/FZW.png
# train/NIS.png
# train/PJYZ.png
# train/LGX.png
# train/MHRB.png
# train/VYYQ.png
# train/ILY.png
# train/GJMV.png
# train/HEPH.png
# train/RBG.png
# train/SMC.png
# train/RDSQ.png
# train/JGO.png
# train/HDR.png
# train/XBHU.png
# train/ATZ.png
# train/WBSD.png
# train/DEM.png
# train/KBHZ.png
# train/AGZF.png
# train/JLIV.png
# train/TAAV.png
# train/HBNV.png
# train/LLEK.png
# train/EXI.png
# train/LOYD.png
# train/FVN.png
# train/LKWW.png
# train/CHYR.png
# train/IRZ.png
# train/KHN.png
# train/ONPK.png
# train/HDOO.png
# train/NLJC.png
# train/NLRN.png
# train/VHOJ.png
# train/DIBZ.png
# train/XKR.png
# train/OJD.png
# train/XCDE.png
# train/EDI.png
# train/GDNE.png
# train/ASX.png
# train/PNWI.png
# train/JYB.png
# train/BVAG.png
# train/NIZK.png
# train/WYJ.png
# train/NVB.png
# train/MZU.png
# train/JRP.png
# train/EGT.png
# train/DZR.png
# train/NMUH.png
# train/PJGI.png
# train/HZEA.png
# train/WAZW.png
# train/MJFQ.png
# train/UAYN.png
# train/WOD.png
# train/DSHP.png
# train/QKBR.png
# train/QXU.png
# train/IXD.png
# train/IJH.png
# train/MPG.png
# train/IJU.png
# train/PAG.png
# train/VITV.png
# train/UPI.png
# train/VKUG.png
# train/CVJW.png
# train/GEA.png
# train/DEO.png
# train/PNJ.png
# train/FYHE.png
# train/IWR.png
# train/RBZ.png
# train/IXJD.png
# train/CMX.png
# train/GBUF.png
# train/HBU.png
# train/UOJT.png
# train/KIV.png
# train/OVC.png
# train/TKX.png
# train/GKB.png
# train/CCJ.png
# train/QXD.png
# train/GOWW.png
# train/MYMH.png
# train/OHT.png
# train/WUW.png
# train/HTS.png
# train/HGLN.png
# train/JWVH.png
# train/ANVB.png
# train/TVH.png
# train/CWIK.png
# train/LRY.png
# train/ESL.png
# train/TJYW.png
# train/BPX.png
# train/EEZ.png
# train/WXA.png
# train/WFMT.png
# train/TWJF.png
# train/QHE.png
# train/HDP.png
# train/WMR.png
# train/ERR.png
# train/NRA.png
# train/WKMG.png
# train/BSM.png
# train/KSS.png
# train/GJNA.png
# train/REN.png
# train/SNI.png
# train/LDH.png
# train/BVR.png
# train/HDZL.png
# train/TNHX.png
# train/EVRH.png
# train/XAO.png
# train/XPTP.png
# train/OND.png
# train/IOKG.png
# train/OGAH.png
# train/FWI.png
# train/WBT.png
# train/FCLV.png
# train/FLDG.png
# train/WYM.png
# train/TBR.png
# train/SDB.png
# train/SQEV.png
# train/HZPZ.png
# train/KQVP.png
# train/GDOJ.png
# train/RCJ.png
# train/XCFW.png
# train/QGNI.png
# train/CKD.png
# train/NJWT.png
# train/ERPE.png
# train/HTZ.png
# train/EXPW.png
# train/NFN.png
# train/VLUK.png
# train/APE.png
# train/TWHE.png
# train/OYXN.png
# train/GKO.png
# train/OSZ.png
# train/JXCO.png
# train/LOWM.png
# train/UWJF.png
# train/WRH.png
# train/SIQJ.png
# train/SDJS.png
# train/PGDN.png
# train/QHAO.png
# train/HHO.png
# train/SGR.png
# train/OXS.png
# train/GGSP.png
# train/TUP.png
# train/HROO.png
# train/CIGW.png
# train/KYZ.png
# train/WZHJ.png
# train/GYF.png
# train/OXSS.png
# train/BHLR.png
# train/PJK.png
# train/FXA.png
# train/UPFO.png
# train/LAWJ.png
# train/JHVD.png
# train/JCNA.png
# train/UOEX.png
# train/TZSC.png
# train/BDFP.png
# train/KZO.png
# train/RSC.png
# train/NHG.png
# train/ENOW.png
# train/KAT.png
# train/UTV.png
# train/TWAM.png
# train/NBP.png
# train/LSUO.png
# train/BEA.png
# train/BVGY.png
# train/AWI.png
# train/CML.png
# train/JPV.png
# train/GJG.png
# train/PQXA.png
# train/GFUV.png
# train/AHLD.png
# train/WBPY.png
# train/OCGD.png
# train/TSS.png
# train/PBJ.png
# train/XGLV.png
# train/XOO.png
# train/RSVF.png
# train/OOS.png
# train/RZW.png
# train/LITS.png
# train/LUS.png
# train/DNF.png
# train/XPAH.png
# train/TKI.png
# train/VTHD.png
# train/RVB.png
# train/LIQ.png
# train/WSV.png
# train/CMJ.png
# train/PWUO.png
# train/XCI.png
# train/KGA.png
# train/MTAI.png
# train/CVOS.png
# train/QUZH.png
# train/EZVK.png
# train/OVZ.png
# train/DWWV.png
# train/CWLB.png
# train/TCM.png
# train/EFY.png
# train/TSA.png
# train/ADTX.png
# train/BAS.png
# train/AXAK.png
# train/PJVZ.png
# train/HPGB.png
# train/NON.png
# train/ETGM.png
# train/GYKW.png
# train/TDOH.png
# train/ENSR.png
# train/MHO.png
# train/GEPQ.png
# train/IAE.png
# train/QRWS.png
# train/MBF.png
# train/GOS.png
# train/PRWO.png
# train/AAGL.png
# train/JPM.png
# train/VHM.png
# train/DIYG.png
# train/JNU.png
# train/MKVT.png
# train/VXNG.png
# train/EIK.png
# train/VKUU.png
# train/LDWY.png
# train/QGL.png
# train/PNUJ.png
# train/FCCW.png
# train/WKE.png
# train/TAMA.png
# train/QHQ.png
# train/KIPS.png
# train/AJGG.png
# train/ULOH.png
# train/XSHA.png
# train/TTU.png
# train/FRL.png
# train/AWB.png
# train/TRY.png
# train/TUR.png
# train/OHZC.png
# train/UKBZ.png
# train/HUW.png
# train/GMVC.png
# train/PLFR.png
# train/PRY.png
# train/IJDS.png
# train/CHS.png
# train/SJUC.png
# train/FEKD.png
# train/RNS.png
# train/KWCG.png
# train/UHL.png
# train/UYQI.png
# train/EJI.png
# train/FWY.png
# train/FGFM.png
# train/MFT.png
# train/EZH.png
# train/WOU.png
# train/EJH.png
# train/RJX.png
# train/IEO.png
# train/MJJ.png
# train/PWJF.png
# train/RZBR.png
# train/JPVK.png
# train/VKQK.png
# train/BAT.png
# train/HWJM.png
# train/MZKT.png
# train/GUAV.png
# train/JFIT.png
# train/UNSR.png
# train/AHMC.png
# train/NFT.png
# train/RTF.png
# train/GYU.png
# train/BEUF.png
# train/MRZ.png
# train/DNJ.png
# train/JJDT.png
# train/PKBU.png
# train/XIVG.png
# train/UHTF.png
# train/SBWX.png
# train/STO.png
# train/EGN.png
# EGN
# 1
# 3
# train/OZM.png
# train/ETRJ.png
# train/HLO.png
# train/EVRY.png
# train/AUK.png
# train/IAF.png
# train/SCX.png
# train/CZDZ.png
# train/QNIZ.png
# train/NXDS.png
# train/UYMB.png
# train/LRV.png
# train/IZT.png
# train/OXN.png
# train/OCS.png
# train/XPKU.png
# train/HGFX.png
# train/PAVG.png
# train/EARK.png
# train/XFN.png
# train/XOC.png
# train/VONC.png
# train/CKSZ.png
# train/PAA.png
# train/HXMO.png
# train/IAXY.png
# train/EDTW.png
# train/IJIV.png
# train/QNS.png
# train/UBBA.png
# train/CVTB.png
# train/HTC.png
# train/TUW.png
# train/ACI.png
# train/TGF.png
# train/WLB.png
# train/LWM.png
# train/LLU.png
# train/GUSV.png
# train/CPL.png
# train/BFAM.png
# train/SVD.png
# train/XNHS.png
# train/CAPB.png
# train/KEKP.png
# train/LBD.png
# train/IZLN.png
# train/PDR.png
# train/TEU.png
# train/TUO.png
# train/VAW.png
# train/LDZ.png
# train/FVVB.png
# train/KFVF.png
# train/UUWY.png
# train/MWZ.png
# train/QCXN.png
# train/GZF.png
# train/LDEV.png
# train/AMG.png
# train/ETI.png
# train/AMI.png
# train/AYDQ.png
# train/SRM.png
# train/ECM.png
# train/NWD.png
# train/WCQB.png
# train/MFW.png
# train/NJKQ.png
# train/GVQ.png
# train/DFC.png
# train/PNWB.png
# train/ADVV.png
# train/HVP.png
# train/PLTG.png
# train/HDOH.png
# train/TVV.png
# train/MVIF.png
# train/UFPA.png
# train/ARWT.png
# train/PBT.png
# train/KBON.png
# train/QQZ.png
# train/DZP.png
# train/AEIK.png
# train/TEJ.png
# train/LNV.png
# train/EGWX.png
# train/TWOJ.png
# train/FDM.png
# train/IOCD.png
# train/ONU.png
# train/FSMF.png
# train/FYEF.png
# train/PEH.png
# train/LGG.png
# train/AYG.png
# train/MRHC.png
# train/MDZQ.png
# train/LEJ.png
# train/COW.png
# train/OADO.png
# train/PDIW.png
# train/AYMM.png
# train/LOX.png
# train/MYJ.png
# train/IQIY.png
# train/RHS.png
# train/MUJI.png
# train/DXJH.png
# train/DSXN.png
# train/UIUV.png
# train/RMS.png
# train/ACKZ.png
# train/SYLR.png
# train/IQEV.png
# train/JQH.png
# train/EWTF.png
# train/KUNG.png
# train/TANW.png
# train/DOO.png
# train/XQI.png
# train/WRI.png
# train/TZCW.png
# train/QDKT.png
# train/NCCV.png
# train/KFDN.png
# train/KPKM.png
# train/HGG.png
# train/MXNY.png
# train/MAMY.png
# train/CBB.png
# train/DSY.png
# train/PFZZ.png
# train/NLO.png
# train/DFY.png
# train/DQH.png
# train/FZUR.png
# train/ERJ.png
# train/OPVG.png
# train/GAN.png
# train/BKHG.png
# train/KTAL.png
# train/SEYM.png
# train/DART.png
# train/EQEL.png
# train/LZGI.png
# train/RAD.png
# train/TKL.png
# train/LZQE.png
# train/NEF.png
# train/OQP.png
# train/PIM.png
# train/RSX.png
# train/HPJU.png
# train/LRMB.png
# train/EOO.png
# train/HEL.png
# train/MKQI.png
# train/ARI.png
# train/JPK.png
# train/PQD.png
# train/KRU.png
# train/BGU.png
# train/TACG.png
# train/VFP.png
# train/JSW.png
# train/AAE.png
# train/QYZQ.png
# train/DQC.png
# train/OEU.png
# train/OVRQ.png
# train/WICO.png
# train/XBQ.png
# train/PYC.png
# train/MXPR.png
# train/NIQQ.png
# train/WFC.png
# train/KIT.png
# train/VSKX.png
# train/TEMC.png
# train/VKN.png
# train/JME.png
# train/HQI.png
# train/FVJI.png
# train/OGKI.png
# train/EVI.png
# train/BOT.png
# train/QHDI.png
# train/THG.png
# train/PYKV.png
# train/LMA.png
# train/TING.png
# train/WCQ.png
# train/CGC.png
# train/KACD.png
# train/OJC.png
# train/HEHM.png
# train/FMQN.png
# train/JWIU.png
# train/ACN.png
# train/AAQI.png
# train/PKFT.png
# train/ULRL.png
# train/GIC.png
# train/FWXT.png
# train/EUUF.png
# train/QZC.png
# train/KUI.png
# train/UPGV.png
# train/USW.png
# train/EXZG.png
# train/HQD.png
# train/LFR.png
# train/XQLO.png
# train/ICD.png
# train/NAO.png
# train/AQVU.png
# train/XQIT.png
# train/GUL.png
# train/WDZ.png
# train/HOJ.png
# train/ISXL.png
# train/DYE.png
# train/FWT.png
# train/QNP.png
# train/LCKZ.png
# train/PJLH.png
# train/OXPU.png
# train/TFX.png
# train/XAC.png
# train/CSB.png
# train/VSW.png
# train/MVAZ.png
# train/MLAF.png
# train/QNJ.png
# train/LBX.png
# train/VZQH.png
# train/OIDT.png
# train/NPM.png
# train/LBXX.png
# train/LAC.png
# train/HBNI.png
# train/COI.png
# train/OAT.png
# train/QXW.png
# train/VKQ.png
# train/FHLQ.png
# train/XOZ.png
# train/QRX.png
# train/PTCP.png
# train/WUT.png
# train/DRYI.png
# train/LWD.png
# train/DUJ.png
# train/CXGJ.png
# train/AJMN.png
# train/PZEC.png
# train/NUQ.png
# train/BLXL.png
# train/OUO.png
# train/QQO.png
# train/TYTB.png
# train/AQO.png
# train/OCGN.png
# train/MVW.png
# train/JIQR.png
# train/CKE.png
# train/KWZX.png
# train/WDOU.png
# train/AAA.png
# train/DST.png
# train/GTS.png
# train/SSVB.png
# train/QQM.png
# train/HZKQ.png
# train/VFDO.png
# train/NOE.png
# train/EYIZ.png
# train/NKV.png
# train/PHIP.png
# train/EKM.png
# train/RJBP.png
# train/IOK.png
# train/AHCD.png
# train/RPFB.png
# train/GFZ.png
# train/GDYV.png
# train/KEFL.png
# train/SAR.png
# train/DCUS.png
# train/UQIX.png
# train/OCEI.png
# train/GSV.png
# train/SPRA.png
# train/MQJ.png
# train/CIV.png
# train/AWVY.png
# train/DYGG.png
# train/VKD.png
# train/GIK.png
# train/OCNJ.png
# train/CBSQ.png
# train/XFRH.png
# train/QRGF.png
# train/KLHA.png
# train/KSJ.png
# train/LNG.png
# train/OLGL.png
# train/PZAY.png
# train/QKEE.png
# train/UPPI.png
# train/DXV.png
# train/WSWD.png
# train/FYA.png
# train/XBYI.png
# train/DQR.png
# train/BNIC.png
# train/HVAB.png
# train/RBO.png
# train/OAN.png
# train/DJI.png
# train/LYBB.png
# train/VOBM.png
# train/SGI.png
# train/KWS.png
# train/TFP.png
# train/BEBQ.png
# train/ESIW.png
# train/XIY.png
# train/MYOE.png
# train/VWLU.png
# train/WRN.png
# train/KOIB.png
# train/UFL.png
# train/CXD.png
# train/SGW.png
# train/DAJ.png
# train/HFD.png
# train/EHSD.png
# train/WUX.png
# train/WGXV.png
# train/NQSP.png
# train/GCVJ.png
# train/EGQY.png
# train/RDLS.png
# train/EAO.png
# train/VCQ.png
# train/IUI.png
# train/KFRZ.png
# train/IOB.png
# train/KRUJ.png
# train/JZRG.png
# train/IDDD.png
# train/DLEB.png
# train/ORD.png
# train/ROQ.png
# train/PFI.png
# train/EIR.png
# train/TOOX.png
# train/VNU.png
# train/HBDV.png
# train/GIMN.png
# train/VZDX.png
# train/STLC.png
# train/KOXA.png
# train/GWBY.png
# train/UUU.png
# train/KOOO.png
# train/LUCE.png
# train/HHI.png
# train/MGR.png
# train/LXH.png
# train/KHA.png
# train/KAE.png
# train/AYF.png
# train/JUNJ.png
# train/UKR.png
# train/QVV.png
# train/OVAZ.png
# train/UBB.png
# train/BRHP.png
# train/SVG.png
# train/NSKT.png
# train/DCMG.png
# train/BTSA.png
# train/LYO.png
# train/MUAO.png
# train/QZP.png
# train/GDFN.png
# train/JDU.png
# train/DLB.png
# train/TSNH.png
# train/QYHM.png
# train/IUX.png
# train/JTVO.png
# train/JZX.png
# train/TYF.png
# train/INU.png
# train/PZQ.png
# train/STG.png
# train/GQPA.png
# train/LYZ.png
# train/FXXU.png
# train/SRN.png
# train/CSF.png
# train/HUS.png
# train/MZBI.png
# train/XFQL.png
# train/HPLY.png
# train/BYP.png
# train/IKP.png
# train/GOG.png
# train/KZGK.png
# train/FEMY.png
# train/UWJO.png
# train/WQSO.png
# train/VUDU.png
# train/WJE.png
# train/LGQM.png
# train/XMN.png
# train/WNW.png
# train/BQMN.png
# train/VCX.png
# train/QIZ.png
# train/QUZU.png
# train/IQBL.png
# train/NELU.png
# train/WBS.png
# train/RJBY.png
# train/UBKF.png
# train/MDZ.png
# train/KXYH.png
# train/UUJ.png
# train/EDY.png
# train/QTBZ.png
# train/IJSJ.png
# train/GFVR.png
# train/SUB.png
# train/CKX.png
# train/NKLN.png
# train/UXFM.png
# train/BBTB.png
# train/DVA.png
# train/QZLS.png
# train/EGD.png
# train/HKYP.png
# train/OEPH.png
# train/MFBL.png
# train/CKCH.png
# train/LIA.png
# train/HGK.png
# train/WJK.png
# train/TZDJ.png
# train/SMR.png
# train/DLL.png
# train/UGJC.png
# train/QHF.png
# train/RMC.png
# train/MVD.png
# train/OIS.png
# train/MXY.png
# train/VIP.png
# train/RQD.png
# train/FSD.png
# train/VCK.png
# train/HRW.png
# train/DNRV.png
# train/BSE.png
# train/BRY.png
# train/HOQR.png
# train/FKI.png
# train/WQSW.png
# train/WNBE.png
# train/BOMD.png
# train/FUW.png
# train/HHA.png
# train/HQAR.png
# train/REV.png
# train/HEO.png
# train/ODJ.png
# train/LDJU.png
# train/FYFZ.png
# train/PWZ.png
# train/TOZY.png
# train/BYHO.png
# train/GLI.png
# train/PEEP.png
# train/NQT.png
# train/FFKT.png
# train/BLG.png
# train/EBPK.png
# train/ORX.png
# train/JGR.png
# train/JKE.png
# train/BMA.png
# train/SQSJ.png
# train/HJI.png
# train/VSN.png
# train/OQU.png
# train/PIG.png
# train/UKU.png
# train/RTR.png
# train/IKE.png
# train/DGA.png
# train/BKEY.png
# train/ENLD.png
# train/CPPO.png
# train/VBBB.png
# train/BMVP.png
# train/CCWU.png
# train/TUM.png
# train/QGX.png
# train/HPL.png
# train/BSPC.png
# train/FGCT.png
# train/ANMH.png
# train/EKH.png
# train/XFH.png
# train/GKVQ.png
# train/PQGD.png
# train/BPO.png
# train/KWM.png
# train/PRS.png
# train/JIY.png
# train/EDRI.png
# train/TWU.png
# train/ICZ.png
# train/EWFH.png
# train/EJUZ.png
# train/HBOR.png
# train/PQKR.png
# train/ERK.png
# train/PZUB.png
# train/EZP.png
# train/SRK.png
# train/TGH.png
# train/HKL.png
# train/VGG.png
# train/NLG.png
# train/DYO.png
# train/DMRX.png
# train/KLVO.png
# train/QBUE.png
# train/HRWY.png
# train/GLG.png
# train/LLB.png
# train/SML.png
# train/MOCN.png
# train/HWLL.png
# train/SCO.png
# train/JGXR.png
# train/CNH.png
# train/UKQX.png
# train/QASL.png
# train/RPQW.png
# train/FLNT.png
# train/WTJ.png
# train/GNBJ.png
# train/QDA.png
# train/MSVM.png
# train/KLPQ.png
# train/TYH.png
# train/NUDB.png
# train/NPNT.png
# train/MYC.png
# train/JIMI.png
# train/ORKI.png
# train/XQS.png
# train/SFA.png
# train/DUU.png
# train/AVXS.png
# train/DUZU.png
# train/SFM.png
# train/PCD.png
# train/GJIU.png
# train/QXQ.png
# train/SPS.png
# train/XJTB.png
# train/QND.png
# train/CWTX.png
# train/NUN.png
# train/NDU.png
# train/NSQ.png
# train/UNPY.png
# train/NNB.png
# train/IKWP.png
# train/IMYJ.png
# train/CFC.png
# train/KDLM.png
# train/RES.png
# train/ASYK.png
# train/CJU.png
# train/NOF.png
# train/WYZG.png
# train/VKS.png
# train/OAKO.png
# train/KCJ.png
# train/OIXU.png
# train/MEMB.png
# train/WUY.png
# train/BGM.png
# train/TXRA.png
# train/VHTI.png
# train/APQO.png
# train/LWKK.png
# train/FSRH.png
# train/XKU.png
# train/PBZ.png
# train/KRS.png
# train/RMUP.png
# train/OFRZ.png
# train/BFN.png
# train/UCBI.png
# train/UNZO.png
# train/TANI.png
# train/ASBH.png
# train/WSSB.png
# train/SGQR.png
# train/XTCY.png
# train/LVL.png
# train/SKO.png
# train/PGG.png
# train/PUQ.png
# train/OXV.png
# train/UIJG.png
# train/HOTI.png
# train/CFI.png
# train/MLB.png
# train/LJF.png
# train/LWBQ.png
# train/HLH.png
# train/OHHW.png
# train/GQWB.png
# train/EYB.png
# train/GGXP.png
# train/OHP.png
# train/BYZ.png
# train/WUMZ.png
# train/GVRE.png
# train/WBLN.png
# train/MBRY.png
# train/ANHL.png
# train/LACN.png
# train/PACK.png
# train/HEZ.png
# train/RUV.png
# train/QXUJ.png
# train/SYVZ.png
# train/EZX.png
# train/WLAU.png
# train/VNWU.png
# train/FBH.png
# train/OQBA.png
# train/BKG.png
# train/EMS.png
# train/HYJX.png
# train/GZSN.png
# train/UDJZ.png
# train/VNT.png
# train/BVKM.png
# train/JNPW.png
# train/WVZF.png
# train/PHL.png
# train/QGTC.png
# train/EVCU.png
# train/ADY.png
# train/AVR.png
# train/AUCS.png
# train/IPKE.png
# train/OCD.png
# train/BRSW.png
# train/AJOX.png
# train/SDTB.png
# train/OTI.png
# train/EJKV.png
# train/PEBN.png
# train/EQP.png
# train/NSZ.png
# train/DUWO.png
# train/LYM.png
# train/BXII.png
# train/FPOU.png
# train/ITV.png
# train/WEG.png
# train/DFO.png
# train/HRI.png
# train/KAP.png
# train/SRY.png
# train/MNXE.png
# train/CTDJ.png
# train/PLB.png
# train/IGCM.png
# train/RGSX.png
# train/EYZ.png
# train/OIBB.png
# train/VBN.png
# train/GCA.png
# train/DLCX.png
# train/SLY.png
# train/POYZ.png
# train/EWUO.png
# train/WRJS.png
# train/NNP.png
# train/PYEV.png
# train/STBO.png
# train/WHK.png
# train/VINX.png
# train/GZO.png
# train/DGUP.png
# train/HWN.png
# train/BYF.png
# train/EACN.png
# train/SPV.png
# train/VWUL.png
# train/BIS.png
# train/EEN.png
# train/PFR.png
# train/DOH.png
# train/SVOI.png
# train/ISJT.png
# train/JLMD.png
# train/VMC.png
# train/PNMF.png
# train/EJD.png
# train/TNEC.png
# train/CKZW.png
# train/FEE.png
# train/LSR.png
# train/GEI.png
# train/EYY.png
# train/XTOV.png
# train/TEDB.png
# train/VSPQ.png
# train/IPH.png
# train/OFNB.png
# train/MAZD.png
# train/RNLK.png
# train/TLM.png
# train/STKF.png
# train/DKI.png
# train/VFHB.png
# train/BHC.png
# train/SKLK.png
# train/IBUJ.png
# train/LFH.png
# train/XAG.png
# train/FVSP.png
# train/FJJW.png
# train/BNB.png
# train/CPG.png
# train/IFOA.png
# train/RSNL.png
# train/QVPS.png
# train/ORE.png
# train/OGQD.png
# train/DCNW.png
# train/PUQR.png
# train/AYSJ.png
# train/MJFF.png
# train/PJPB.png
# train/KLDQ.png
# train/NVXH.png
# train/WHDQ.png
# train/IFX.png
# train/AUYK.png
# train/VMOS.png
# train/QUA.png
# train/MIZH.png
# train/LHSX.png
# train/BKB.png
# train/MJT.png
# train/IRGW.png
# train/MUP.png
# train/KOIK.png
# train/ARQ.png
# train/GPQP.png
# train/VDK.png
# train/GYD.png
# train/IUZ.png
# train/HUX.png
# train/PWO.png
# train/GHK.png
# train/MJNU.png
# train/BCQ.png
# train/BWE.png
# train/KAF.png
# train/RUQ.png
# train/HXV.png
# train/PDXG.png
# train/NXO.png
# train/XPD.png
# train/QLCT.png
# train/XNV.png
# train/KODQ.png
# train/JSD.png
# train/BCEM.png
# train/OZSD.png
# train/UCS.png
# train/QIQT.png
# train/CPSB.png
# train/LRL.png
# train/FUC.png
# train/KWOF.png
# train/XMMG.png
# train/RVQ.png
# train/RSDG.png
# train/BGUB.png
# train/PIOO.png
# train/KBF.png
# train/NTL.png
# train/WOO.png
# train/CEH.png
# train/VNMP.png
# train/BOZ.png
# train/BUF.png
# train/RME.png
# train/LDMT.png
# train/FHNS.png
# train/KDEJ.png
# train/PMT.png
# train/EPMU.png
# train/FUYH.png
# train/FKPX.png
# train/ARFQ.png
# train/LCWF.png
# train/DBRW.png
# train/CXW.png
# train/IQW.png
# train/DXQL.png
# train/NVPD.png
# train/WGL.png
# train/RHTJ.png
# train/KDIA.png
# train/OZLS.png
# train/XOX.png
# train/QPAP.png
# train/NYN.png
# train/HDNW.png
# train/IVQ.png
# train/PYBW.png
# train/XQY.png
# train/ONR.png
# train/CPO.png
# train/WOP.png
# train/VCS.png
# train/FQIV.png
# train/XTA.png
# train/AGIA.png
# train/UOTE.png
# train/QGP.png
# train/QARO.png
# train/TUY.png
# train/TGL.png
# train/RGW.png
# train/AGQ.png
# train/ACD.png
# train/EAS.png
# train/PAS.png
# train/UGJ.png
# train/NLP.png
# train/MAQB.png
# train/ISK.png
# train/OEX.png
# train/MQJP.png
# train/FJRN.png
# train/LHZH.png
# train/KCSK.png
# train/UQC.png
# train/PHD.png
# train/LUP.png
# train/LDYN.png
# train/JSMS.png
# train/PSWK.png
# train/RYXY.png
# train/NQBG.png
# train/SHO.png
# train/QDN.png
# train/RVEM.png
# train/FMO.png
# train/MNZ.png
# train/LHJ.png
# train/QFS.png
# train/GKP.png
# train/IOLQ.png
# train/VBA.png
# train/QDMK.png
# train/ENSU.png
# train/PSRC.png
# train/DBBQ.png
# train/LZBL.png
# train/HHC.png
# train/WQRE.png
# train/HEPO.png
# train/KXV.png
# train/LPR.png
# train/ITRM.png
# train/EAE.png
# train/EEYK.png
# train/LTW.png
# train/ECGH.png
# train/IOA.png
# train/NEIK.png
# train/EVF.png
# train/NOA.png
# train/SAI.png
# train/EEBE.png
# train/GSSJ.png
# train/NFQ.png
# train/WSU.png
# train/BDI.png
# train/IOMG.png
# train/MKQZ.png
# train/NOIY.png
# train/BIU.png
# train/PCQG.png
# train/DEL.png
# train/ALBS.png
# train/POGK.png
# train/KZN.png
# train/RPAX.png
# train/EDH.png
# train/SRB.png
# train/QAIZ.png
# train/KRQ.png
# train/HYJ.png
# train/JGNE.png
# train/XAOR.png
# train/RQSL.png
# train/EQHA.png
# train/JCVC.png
# train/RFL.png
# train/WGW.png
# train/WUJ.png
# train/DJVA.png
# train/EZVI.png
# train/TNEJ.png
# train/ENZ.png
# train/TLIP.png
# train/SSH.png
# train/HDZW.png
# train/CYG.png
# train/TIQ.png
# train/GWVG.png
# train/MDB.png
# train/QRP.png
# train/UMFV.png
# train/RCRY.png
# train/GDHQ.png
# train/PEAN.png
# train/SUZ.png
# train/DEHW.png
# train/JPRO.png
# train/AXLM.png
# train/SFI.png
# train/WXC.png
# train/XDV.png
# train/QUKM.png
# train/SCHS.png
# train/FCM.png
# train/WFW.png
# train/CFW.png
# train/VEFL.png
# train/UORG.png
# train/FNTV.png
# train/RJN.png
# train/CUO.png
# train/DQWX.png
# train/XIZK.png
# train/POZI.png
# train/KXY.png
# train/OJM.png
# train/VFEU.png
# train/BLXY.png
# train/GBRO.png
# train/CGCT.png
# train/OJI.png
# train/CIPL.png
# train/GMO.png
# train/KQV.png
# train/VMCS.png
# train/MNC.png
# train/PLL.png
# train/LFUC.png
# train/JEBN.png
# train/CSZ.png
# train/APHK.png
# train/IXR.png
# train/XQW.png
# train/UQZ.png
# train/XDO.png
# train/BLN.png
# train/ONT.png
# train/QGQ.png
# train/QPP.png
# train/TFNX.png
# train/SQHR.png
# train/PJX.png
# train/AFD.png
# train/KXYB.png
# train/UHG.png
# train/TKHG.png
# train/ACA.png
# train/BOGE.png
# train/BZH.png
# train/HBNP.png
# train/OBN.png
# train/MMOW.png
# train/UIHP.png
# train/CGDQ.png
# train/CBX.png
# train/EFN.png
# train/JIJY.png
# train/OXP.png
# train/MFD.png
# train/GIMC.png
# train/WSB.png
# train/LGB.png
# train/JCRI.png
# train/ABU.png
# train/ANJ.png
# train/ICB.png
# train/VIEK.png
# train/JLC.png
# train/JNK.png
# train/UFFS.png
# train/DPU.png
# train/OQB.png
# train/QRY.png
# train/QOKZ.png
# train/RLCK.png
# train/LVHX.png
# train/WTSP.png
# train/XDM.png
# train/EKX.png
# train/NFS.png
# train/ATK.png
# train/MOL.png
# train/QGNR.png
# train/DFZ.png
# train/BMB.png
# train/PVRL.png
# train/ESY.png
# train/DVQ.png
# train/FMID.png
# train/JOZ.png
# train/PQAX.png
# train/SDWF.png
# train/GEXI.png
# train/RUN.png
# train/MXWG.png
# train/EPLY.png
# train/BRTA.png
# train/XMV.png
# train/VAVS.png
# train/QGU.png
# train/FYB.png
# train/VEXM.png
# train/RFAE.png
# train/OUS.png
# train/OAY.png
# train/UYPK.png
# train/XGN.png
# train/GYX.png
# train/MOA.png
# train/VMQ.png
# train/FZPA.png
# train/RYUA.png
# train/MDJ.png
# train/AZTP.png
# train/SAE.png
# train/SID.png
# train/RDOT.png
# train/QXTF.png
# train/NCV.png
# train/KFY.png
# train/FJCU.png
# train/QIZL.png
# train/SMU.png
# train/ASXG.png
# train/BZUF.png
# train/FXP.png
# train/SDYL.png
# train/HKO.png
# train/KQEP.png
# train/OPIY.png
# train/QTB.png
# train/MAM.png
# train/QUO.png
# train/PLT.png
# train/ADB.png
# train/MIT.png
# train/KSRL.png
# train/PLWB.png
# train/LLA.png
# train/PWML.png
# train/BSJ.png
# train/OHS.png
# train/EONP.png
# train/PPKG.png
# train/QGGN.png
# train/FOJ.png
# train/KVYQ.png
# train/IOIZ.png
# train/WFD.png
# train/VAT.png
# train/IROX.png
# train/BLFI.png
# train/JGQG.png
# train/OKDD.png
# train/PYY.png
# train/HCHX.png
# train/OVM.png
# train/MAYQ.png
# train/DPWL.png
# train/CMJH.png
# train/SCZB.png
# train/QLJ.png
# train/LEP.png
# train/GAD.png
# train/UAMV.png
# train/KXT.png
# train/XDG.png
# train/QDC.png
# train/KJRC.png
# train/GWZI.png
# train/VDP.png
# train/SSB.png
# train/LQX.png
# train/NPNB.png
# train/TXV.png
# train/QTN.png
# train/CSWP.png
# train/XPOF.png
# train/SPXG.png
# train/XHC.png
# train/CXDH.png
# train/ETO.png
# train/AWS.png
# train/JSC.png
# train/IRFH.png
# train/BJM.png
# train/WDGI.png
# train/AEDC.png
# train/RWCP.png
# train/NKL.png
# train/BYY.png
# train/MDP.png
# train/REP.png
# train/SKIK.png
# train/QPOU.png
# train/WUSY.png
# train/IFTW.png
# train/UZS.png
# train/UBS.png
# train/GMRK.png
# train/JWL.png
# train/URW.png
# train/ACWT.png
# train/LQDS.png
# train/TWS.png
# train/FGI.png
# train/DQS.png
# train/JGA.png
# train/TUS.png
# train/XJS.png
# train/JIMT.png
# train/CNLT.png
# train/ISJ.png
# train/DFXK.png
# train/EDIU.png
# train/SKGO.png
# train/KZZY.png
# train/DVKF.png
# train/BHAE.png
# train/NLPV.png
# train/IFXW.png
# train/EZS.png
# train/OBIA.png
# train/KXZ.png
# train/UXLJ.png
# train/DKLD.png
# train/GEHM.png
# train/OXZ.png
# train/QNOH.png
# train/JYA.png
# train/SJZ.png
# train/MKZF.png
# train/EDV.png
# train/CDD.png
# train/ALZM.png
# train/KLUE.png
# train/NJFX.png
# train/VMRR.png
# train/SNJ.png
# train/RCI.png
# train/FOZL.png
# train/UPUE.png
# train/XTDM.png
# train/KIM.png
# train/SSXN.png
# train/SGU.png
# train/VPAO.png
# train/VMT.png
# train/DGD.png
# train/BIP.png
# train/MYQP.png
# train/LME.png
# train/FZF.png
# train/HZKX.png
# train/JXCJ.png
# train/KHDC.png
# train/PBY.png
# train/UBJ.png
# train/VDFM.png
# train/USB.png
# train/DKM.png
# train/IDRN.png
# train/MJZ.png
# train/NYRY.png
# train/TJC.png
# train/OLL.png
# train/KOGM.png
# train/FWW.png
# train/IFWZ.png
# train/NFBC.png
# train/KVSN.png
# train/CHZ.png
# train/LIE.png
# train/GUEX.png
# train/LTOU.png
# train/RMJ.png
# train/QDRR.png
# train/KUG.png
# train/CWH.png
# train/VTNE.png
# train/QATM.png
# train/ICSZ.png
# train/OWG.png
# train/KLK.png
# train/EBUK.png
# train/FAW.png
# train/LXG.png
# train/INUD.png
# train/GPNN.png
# train/LTOT.png
# 34.226700270024594

# %%
# training a model 
X = []
y = []
solved_letters = glob.glob(os.path.join("split_img/*", "*"))
for i,img in enumerate(solved_letters):
    try:
        txt = img.split('/')[1]
#         yi =np.zeros(26)
#         yi[ord(txt)-65] =1
#             print(img)
        yi = ord(txt)-65
        img = cv2.imread(img,0)
        dim = (28,28)
        img = cv2.resize(img, dim, interpolation = cv2.INTER_AREA)
        img = img.reshape(-1)
        X.append(np.array(img))
        y.append(yi)
#         print(img.shape)
#         break
    except:
        print("Not a image")

# %%
X = np.array(X)
y = np.array(y)
print(X.shape)
print(y.shape)
# Out:
# (7006, 784)
# (7006,)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20, random_state=42)
print(X_train)
# Out:
# [[255 255 255 ... 255 255 255]
#  [255 255 255 ... 255 255 255]
#  [255 255 255 ... 255 255 255]
#  ...
#  [255 255 255 ... 255 255 255]
#  [255 255 255 ... 255 255 255]
#  [255 255 255 ... 255 255 255]]

# %%
X_train = X_train.reshape(X_train.shape[0], 28, 28, 1)
X_test = X_test.reshape(X_test.shape[0], 28, 28, 1)
X_train = X_train.astype('float32')
X_test = X_test.astype('float32')
# Normalizing the RGB codes by dividing it to the max RGB value.
X_train /= 255
X_test /= 255

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Conv2D, Dropout, Flatten, MaxPooling2D
# Creating a Sequential Model and adding the layers
input_shape = (28, 28, 1)
model = Sequential()
model.add(Conv2D(28, kernel_size=(3,3), input_shape=input_shape))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Flatten()) # Flattening the 2D arrays for fully connected layers
model.add(Dense(128, activation=tf.nn.relu))
model.add(Dropout(0.2))
model.add(Dense(26,activation=tf.nn.softmax))
model.summary()
# Out:
# WARNING:tensorflow:From /home/avesh/anaconda3/lib/python3.7/site-packages/tensorflow_core/python/ops/resource_variable_ops.py:1630: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 26, 26, 28)        280
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 13, 13, 28)        0
# _________________________________________________________________
# flatten (Flatten)            (None, 4732)              0
# _________________________________________________________________
# dense (Dense)                (None, 128)               605824
# _________________________________________________________________
# dropout (Dropout)            (None, 128)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 26)                3354
# =================================================================
# Total params: 609,458
# Trainable params: 609,458
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(optimizer = 'adam', loss = 'sparse_categorical_crossentropy', metrics = ['accuracy'])
model.fit( X_train, y_train, epochs=5)
# Out:
# Train on 5604 samples
# Epoch 1/5
# 5604/5604 [==============================] - 4s 747us/sample - loss: 0.0223 - acc: 0.9938
# Epoch 2/5
# 5604/5604 [==============================] - 4s 691us/sample - loss: 0.0222 - acc: 0.9939
# Epoch 3/5
# 5604/5604 [==============================] - 4s 687us/sample - loss: 0.0204 - acc: 0.9938
# Epoch 4/5
# 5604/5604 [==============================] - 4s 684us/sample - loss: 0.0184 - acc: 0.9955
# Epoch 5/5
# 5604/5604 [==============================] - 4s 700us/sample - loss: 0.0134 - acc: 0.9975

# %%
tic = tm.perf_counter()
model.evaluate(X_test, y_test)
# model.evaluate(X_train, y_train)
toc = tm.perf_counter()

print( "Total time taken is %.6f seconds " % (toc - tic) )
# Out:
# 1402/1402 [==============================] - 1s 404us/sample - loss: 0.0070 - acc: 0.9986
# Total time taken is 0.589142 seconds

# %%
model.save("model.h5")
